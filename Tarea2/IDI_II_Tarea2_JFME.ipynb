# %% [markdown]
# <img src="http://oci02.img.iteso.mx/identidad_de_instancia_2018/ITESO/Logos%20ITESO/Logo-ITESO-Principal.jpg">

# %% [markdown]
# <center> <font color= #004A94> <font size = 6> Msc Ciencia de datos </font> <br> <br> <font color= #047CFB> <font size = 4>I.F. Juan Francisco Muñoz Elguezabal - franciscome@iteso.mx </font>

# %% [markdown]
# <center> <font color= #42c29b> <font size = 6> Fundamentos Matemáticos de Ciencia de Datos </font> <br> <br>
# <center> <font color= #42caaa> <font size = 4> Tarea2 - Campos Vectoriales y Campos Escalares </font> <br> <br>
# <center> <font color= #a9a9a9> <font size = 4> Repositorio: <a href='https://github.com/IFFranciscoME/FMCD_GIT'>Link</a></font>

# %% [markdown]
# ---

# %% [markdown]
# ## Ejercicio 23

# %%
x <- seq(-10, 10, length = 50)
y <- seq(-10, 10, length = 50)

z <- outer(x, y, function(x,y) {
    r <- sqrt(x^2 + y^2)+3
    return (sin(r)/r)
})

# %%
persp(x, y, z,
      theta  = 15,                      # Rotacion en el eje Z (en grados)
      phi    = 40,                      # Rotacion en el eje X (en grados)
      expand =  1,                      # Escalar los valores de Z
      border = '#333333',               # Color del borde (En hexadecimal)
      col    = c('#bbddff', '#ddbbff'), # Color de valores (En hexadecimal)
      shade  =  0.5)                    # Contraste de sombra proyectada)
# Out:
# plot without title
